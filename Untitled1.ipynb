# %% [markdown]
# In this file we extract data from Pdf to docx

# %%
pip install pytesseract pdf2image pillow python-docx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract
from pdf2image import convert_from_path
from PIL import Image
from docx import Document
import os


pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

poppler_path = r"C:\Program Files\poppler\Library\bin"  


pdf_path = "Books/G12-Ps-Civic.pdf"

images = convert_from_path(pdf_path, dpi=300, poppler_path=poppler_path)

doc = Document()

for i, img in enumerate(images):
    print(f"Processing page {i+1}...")
    text = pytesseract.image_to_string(img, lang='pus')  # 'pus' is Pashto
    cleaned = text.strip()
    if cleaned:
        doc.add_paragraph(cleaned)
    else:
        doc.add_paragraph(f"[Page {i+1} had no readable text]")

output_path = os.path.splitext(pdf_path)[0] + "_extracted.docx"
doc.save(output_path)

print(f"✅ Extraction complete! Saved to: {output_path}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pdf2image\pdf2image.py:602, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout, first_page, last_page)
#     601 if "Pages" not in d:
# --> 602     raise ValueError
#     604 return d
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# Cell In[4], line 15
#      10 poppler_path = r"C:\Program Files\poppler\Library\bin"
#      13 pdf_path = "Books/G12-Ps-Civic.pdf"
# ---> 15 images = convert_from_path(pdf_path, dpi=300, poppler_path=poppler_path)
#      17 doc = Document()
#      19 for i, img in enumerate(images):
#
# ...

# %%
import pytesseract
from pdf2image import convert_from_path
from PIL import Image
from docx import Document
import os

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

poppler_path = r"C:\Program Files\poppler\Library\bin"

pdf_path = "G12/G12-Ps-Civic.pdf"

images = convert_from_path(pdf_path, dpi=400, poppler_path=poppler_path)

doc = Document()

for i, img in enumerate(images):
    print(f"Processing page {i+1}/{len(images)}...")
    img = img.convert('L')  # grayscale for better OCR
    text = pytesseract.image_to_string(img, lang='pus')
    cleaned = text.strip()
    if cleaned:
        doc.add_paragraph(cleaned)
    else:
        doc.add_paragraph(f"[Page {i+1} had no readable text]")


output_path = os.path.splitext(pdf_path)[0] + "_extracted.docx"
doc.save(output_path)
print(f"✅ Extraction complete! Saved to: {output_path}")
# Out:
# Processing page 1/122...
# Processing page 2/122...
# Processing page 3/122...
# Processing page 4/122...
# Processing page 5/122...
# Processing page 6/122...
# Processing page 7/122...
# Processing page 8/122...
# Processing page 9/122...
# Processing page 10/122...
# Processing page 11/122...
# Processing page 12/122...
# Processing page 13/122...
# Processing page 14/122...
# Processing page 15/122...
# Processing page 16/122...
# Processing page 17/122...
# Processing page 18/122...
# Processing page 19/122...
# Processing page 20/122...
# Processing page 21/122...
# Processing page 22/122...
# Processing page 23/122...
# Processing page 24/122...
# Processing page 25/122...
# Processing page 26/122...
# Processing page 27/122...
# Processing page 28/122...
# Processing page 29/122...
# Processing page 30/122...
# Processing page 31/122...
# Processing page 32/122...
# Processing page 33/122...
# Processing page 34/122...
# Processing page 35/122...
# Processing page 36/122...
# ...
